# %%
# libraries

from os import name 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
# creating data

df = pd.read_csv("./data.csv", sep = '\s+')
df.head()
# Out:
#     it      t        dt     torqint_2     torqext_2     torqint_3  \
# 0    0  0.000  0.000186 -2.151000e-19 -2.711000e-19 -4.964000e-19
# 1   50  0.009  0.000186  4.220000e-11 -4.574000e-11  3.761000e-12
# 2  100  0.019  0.000186  3.375000e-10 -3.658000e-10  3.011000e-11
# 3  150  0.028  0.000186  1.139000e-09 -1.234000e-09  1.017000e-10
# 4  200  0.037  0.000186  2.698000e-09 -2.923000e-09  2.411000e-10
#
#       torqext_3     xq1    yq1  xq3  ...      vxq2    vyq2          vxq1  \
# 0 -5.794000e-19  0.0003 -3.142  2.0  ...  0.000000  0.9998  0.000000e+00
# 1 -4.054000e-12  0.0003 -3.136  2.0  ...  0.000002  0.9998 -2.566000e-07
# 2 -3.243000e-11  0.0003 -3.131  2.0  ...  0.000005  0.9998 -5.131000e-07
# 3 -1.094000e-10  0.0003 -3.126  2.0  ...  0.000007  0.9998 -7.696000e-07
# 4 -2.594000e-10  0.0003 -3.120  2.0  ...  0.000010  0.9998 -1.026000e-06
#
#        vyq1  dtv  dtdiffus     umax    rhomin  rhom   rhomax
# 0  0.000171  1.0  0.000128  1.57916  1.000000   1.0  1.00000
# ...

# %%
# using labels to plot multiple columns by only using the number of the columns

labels = ["it", "t", "dt", "torqint_2", "torqext_2", "torqint_3", "torqext_3", "xq1", "yq1", "xq3",
            "yq3", "vxq3", "vyq3", "xq2", "yq2", "vxq2", "vyq2", "vxq1", "vyq1", "dtv",
            "dtdiffus", "umax", "rhomin", "rhom", "rhomax" ]

# using the dropna cmd to remove rows and columns with Null/NaN values

database = df[labels].dropna(how="any") 
vals = df.values
plt.figure(figsize=(14,9.5))
plt.xlabel("Time")  
plt.ylabel("xq1")  
plt.title("Distance of Object 1 in R Direction vs Time")  
plt.plot(vals[:, 1], vals[:, 7], color = 'w') 
plt.savefig('Distance of Object 1 in R Direction vs Time.jpg', format='jpg', dpi=500) 

# to debug use ::100, 0 (100 or whatever # is to check for every 100th line)

# %%
l = 8
plt.figure(figsize=(14,9.5))
plt.title("Δθ for Object 1 vs Time") 
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Δθ for Object 1 vs Time.jpg', format='jpg', dpi=500)

# %%
l = 14
plt.figure(figsize=(14,9.5))
plt.xlim(0, 6.28)
plt.title("Δθ for Object 1 vs Time") 
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Δθ for Object 1 vs Time.jpg', format='jpg', dpi=500)

# %%
l = 17
plt.figure(figsize=(14,9.5))
vals = df.values
plt.title("Velocity of Object 1 in R Direction vs Time") 
plt.xlabel("Time") 
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], color = 'w')
plt.savefig('Velocity of Object 1 in R Direction vs Time.jpg', format='jpg', dpi=500)

# %%
l = 18
plt.figure(figsize=(14,9.5))
plt.title("Velocity of Object 1 (Δθ) vs Time") 
plt.xlabel("Time") 
plt.ylabel(labels[l]) 
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Velocity of Object 1 (Δθ) vs Time.jpg', format='jpg', dpi=500)

# %%
l = 15
plt.figure(figsize=(14,9.5))
plt.title("Distance of Object 2 in R Direction vs Time")  
plt.xlabel("Time")  
plt.ylabel(labels[l]) 
plt.style.use('dark_background')
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Distance of Object 2 in R Direction vs Time.jpg', format='jpg', dpi=500)

# %%
l = 16
plt.figure(figsize=(14,9.5))
plt.title("Δθ of Object 2 vs Time")  
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Δθ of Object 2 vs Time.jpg', format='jpg', dpi=500)

# %%
l = 17
plt.figure(figsize=(14,9.5))
plt.title("Velocity of Object 2 in R Direction vs Time")  
plt.xlabel("Time")  
plt.ylabel(labels[l]) 
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Δθ of Object 2 vs Time.jpg', format='jpg', dpi=500)

# %%
l = 18
plt.figure(figsize=(14,9.5))
plt.title("Velocity of Object 2 (Δθ) vs Time") 
plt.xlabel("Time")  
plt.ylabel(labels[l]) 
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Velocity of Object 2 (Δθ) vs Time.jpg', format='jpg', dpi=500)

# %%
l = 9
plt.figure(figsize=(14,9.5))
plt.title("Distance of Object 3 in R Direction vs Time") 
plt.xlabel("Time") 
plt.ylabel(labels[l]) 
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Distance of Object 3 in R Direction vs Time.jpg', format='jpg', dpi=500)

# %%
l = 12
plt.figure(figsize=(14,9.5))
plt.title("Δθ of Object 3")  
plt.xlabel("Time") 
plt.ylabel(labels[l]) 
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Δθ of Object 3.jpg', format='jpg', dpi=500)

# %%
l = 13
plt.figure(figsize=(14,9.5))
plt.title("Velocity of object 3 in R direction vs Time")  
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Velocity of object 3 in R direction vs Time.jpg', format='jpg', dpi=500)

# %%
l = 14
plt.figure(figsize=(14,9.5))
plt.title("Velocity of Object 3 (Δθ) vs Time")  
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Velocity of Object 3 (Δθ) vs Time.jpg', format='jpg', dpi=500)

# %%
l = 3
plt.figure(figsize=(14,9.5))
plt.title("Internal Torque on Object 2") 
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Internal Torque on Object 2.jpg', format='jpg', dpi=500)

# %%
l = 4
plt.figure(figsize=(14,9.5))
plt.title("External Torque on Object 2") 
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('External Torque on Object 2.jpg', format='jpg', dpi=500)

# %%
l = 5
plt.figure(figsize=(14,9.5))
plt.title("Internal Torque on Object 3") 
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('Internal Torque on Object 3.jpg', format='jpg', dpi=500)

# %%
l = 6
plt.figure(figsize=(14,9.5))
plt.title("External Torque on Object 3") 
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], vals[:, l], ms = .6, color = 'w')
plt.savefig('External Torque on Object 3.jpg', format='jpg', dpi=500)

# %%
l = 3
plt
plt.figure(figsize=(14,9.5))
plt.title("Net Torque on Object 2") 
plt.xlabel("Time")  
plt.ylabel(labels[l]+labels[l+1])  
plt.plot(vals[:, 1], (vals[:, l]+ vals[:, l+1]), ms = .6, color = 'w')
plt.savefig('Net Torque on Object 2.jpg', format='jpg', dpi=500)

# %%
l = 5
plt
plt.figure(figsize=(14,9.5))
plt.title("Net Torque on Object 3") 
plt.xlabel("Time")  
plt.ylabel(labels[l])  
plt.plot(vals[:, 1], (vals[:, l]+ vals[:, l+1]), ms = .6, color = 'w')
plt.savefig('Net Torque on Object 3.jpg', format='jpg', dpi=500)
